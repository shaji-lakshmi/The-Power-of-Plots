# %% [markdown]
# ## Observations and Insights

# %% [markdown]
# #### Three observations made based on the data:
# Capomulin, Ramicane, Infubinol, and Ceftamin
# 1. Within the study, the two drugs that were administered in the most amount of mice were "Capomulin"(230) and "Ramicane"(228). {Based on bar graphs}
#
# 2. When comparing the final tumor volumes in mice on four drugs (Capomulin, Ramicane, Infubinol, and Ceftamin), data shows that the tumor volumes for mice on Infubinol and Ceftamin were alot higher than Capomulin and Rumicane. This could indicate that Capomulin and Ramicane are more effective in reducing the total tumor volumes compared to the other drugs. {Refer to boxplot}
#
# 3. Based on the scatter plot made to analyse the correlation between tumor volume and weight, the data shows that a larger weight of a mouse will indicate a larger tumor volume. Therefore, a suggestion could be made to use mice that weight around the same weight when conducting the study so that measuring tumor volumes( whether it is growth or a decrease) is more accurate across all drugs without weight being an influential factor in the collection tumor volume.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
from scipy.stats import linregress

# Study data files
mouse_metadata_path = "data/Mouse_metadata.csv"
study_results_path = "data/Study_results.csv"

# Read the mouse data and the study results
mouse_metadata = pd.read_csv(mouse_metadata_path)
study_results = pd.read_csv(study_results_path)

# Combine the data into a single dataset
combined_data = pd.merge(mouse_metadata,study_results,on="Mouse ID")
# Display the data table for preview
combined_data
# Out:
#      Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane  Male          21          16          0
# 1        k403     Ramicane  Male          21          16          5
# 2        k403     Ramicane  Male          21          16         10
# 3        k403     Ramicane  Male          21          16         15
# 4        k403     Ramicane  Male          21          16         20
# ...       ...          ...   ...         ...         ...        ...
# 1888     z969     Naftisol  Male           9          30         25
# 1889     z969     Naftisol  Male           9          30         30
# 1890     z969     Naftisol  Male           9          30         35
# 1891     z969     Naftisol  Male           9          30         40
# 1892     z969     Naftisol  Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0              45.000000                 0
# 1              38.825898                 0
# ...

# %%
# Checking the number of mice.
dataCount = combined_data.shape[0]
miceCount = len(pd.unique(combined_data['Mouse ID']))
print(f"Whole dataset: {dataCount}")
print(f"Unique mouse count: {miceCount}")
# Out:
# Whole dataset: 1893
# Unique mouse count: 249

# %%
# Getting the duplicate mice by ID number that shows up for Mouse ID and Timepoint. 
duplicateMice = combined_data[combined_data.duplicated(subset=['Mouse ID'])]
duplicateMice
# Out:
#      Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 1        k403     Ramicane  Male          21          16          5
# 2        k403     Ramicane  Male          21          16         10
# 3        k403     Ramicane  Male          21          16         15
# 4        k403     Ramicane  Male          21          16         20
# 5        k403     Ramicane  Male          21          16         25
# ...       ...          ...   ...         ...         ...        ...
# 1888     z969     Naftisol  Male           9          30         25
# 1889     z969     Naftisol  Male           9          30         30
# 1890     z969     Naftisol  Male           9          30         35
# 1891     z969     Naftisol  Male           9          30         40
# 1892     z969     Naftisol  Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 1              38.825898                 0
# 2              35.014271                 1
# ...

# %%
# Create a clean DataFrame by dropping the duplicate mouse by its ID.
cleanedData = combined_data.drop_duplicates(subset=['Mouse ID'], keep='last')
cleanedData

#Reference: https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.drop_duplicates.html#pandas.DataFrame.drop_duplicates
#Reference: https://stackoverflow.com/questions/12497402/python-pandas-remove-duplicates-by-columns-a-keeping-the-row-with-the-highest
# Out:
#      Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 9        k403     Ramicane    Male          21          16         45
# 19       s185    Capomulin  Female           3          17         45
# 29       x401    Capomulin  Female          16          15         45
# 39       m601    Capomulin    Male          22          17         45
# 49       g791     Ramicane    Male          11          16         45
# ...       ...          ...     ...         ...         ...        ...
# 1859     z314     Stelasyn  Female          21          28          5
# 1862     z435     Propriva  Female          12          26         10
# 1872     z581    Infubinol  Female          24          25         45
# 1882     z795     Naftisol  Female          13          29         45
# 1892     z969     Naftisol    Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 9              22.050126                 1
# ...

# %%
# Checking the number of mice in the clean DataFrame.
cleanCount = cleanedData.shape[0]
print(f"Clean data count: {cleanCount}")
# Out:
# Clean data count: 249

# %% [markdown]
# ## Summary Statistics

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen

# Use groupby and summary statistical methods to calculate the following properties of each drug regimen: 
# mean, median, variance, standard deviation, and SEM of the tumor volume. 
# Assemble the resulting series into a single summary dataframe.
myGroupBy = cleanedData.groupby('Drug Regimen')
meanVal = myGroupBy['Tumor Volume (mm3)'].mean()
medianVal = myGroupBy['Tumor Volume (mm3)'].median()
varianceVal = myGroupBy['Tumor Volume (mm3)'].var()
sdVal = myGroupBy['Tumor Volume (mm3)'].std()
semVal = myGroupBy['Tumor Volume (mm3)'].sem()

statsTable = pd.DataFrame({"Mean": meanVal,
                          "Median": medianVal,
                          "Variance": varianceVal,
                          "Standard Deviation": sdVal,
                          "SEM": semVal})
statsTable
# Out:
#                    Mean     Median    Variance  Standard Deviation       SEM
# Drug Regimen
# Capomulin     36.667568  38.125164   32.663378            5.715188  1.143038
# Ceftamin      57.753977  59.851956   69.982735            8.365568  1.673114
# Infubinol     58.178246  60.165180   74.010875            8.602957  1.720591
# Ketapril      62.806191  64.487812   98.921330            9.945920  1.989184
# Naftisol      61.205757  63.283288  106.029927           10.297083  2.059417
# Placebo       60.508414  62.030594   78.759797            8.874672  1.774934
# Propriva      56.736964  55.841410   69.349002            8.327605  1.665521
# Ramicane      36.191390  36.561652   32.166354            5.671539  1.134308
# Stelasyn      61.001707  62.192350   90.331586            9.504293  1.940056
# Zoniferol     59.181258  61.840058   76.862027            8.767099  1.753420

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen

# Using the aggregation method, produce the same summary statistics in a single line

summaryTable = combined_data['Drug Regimen'].value_counts()
final = pd.DataFrame(summaryTable)
final
# Out:
#            Drug Regimen
# Capomulin           230
# Ramicane            228
# Ketapril            188
# Naftisol            186
# Zoniferol           182
# Stelasyn            181
# Placebo             181
# Infubinol           178
# Ceftamin            178
# Propriva            161

# %% [markdown]
# ## Bar and Pie Charts

# %%
# Generate a bar plot showing the total number of timepoints for all mice tested for each drug regimen using Pandas.
final.plot(kind="bar")
plt.xlabel("Drug Name")
plt.ylabel("Drug Totals")
plt.title("Total Timepoints per Drug")
plt.show()

# %%
# Generate a bar plot showing the total number of timepoints for all mice tested for each drug regimen using pyplot.
xAxis = final.index 
yAxis = final["Drug Regimen"]

plt.bar(xAxis,yAxis)
plt.xlabel("Drug Name")
plt.ylabel("Drug Totals")
plt.title("Total Timepoints per Drug")
plt.xticks(rotation=90)
plt.show()

# %%
# Generate a pie plot showing the distribution of female versus male mice using Pandas
genderStats = cleanedData['Sex'].value_counts()
genderStats


gender_pandas = genderStats.plot(kind="pie", y="sex",autopct="%1.1f%%")
gender_pandas.set_ylabel("Sex")
plt.show()

# %%
# Generate a pie plot showing the distribution of female versus male mice using pyplot
plt.pie(genderStats, labels=genderStats.index,autopct="%1.1f%%")
plt.show()

# %% [markdown]
# ## Quartiles, Outliers and Boxplots

# %%
# Calculate the final tumor volume of each mouse across four of the treatment regimens:  
# Capomulin, Ramicane, Infubinol, and Ceftamin
# Start by getting the last (greatest) timepoint for each mouse
# Merge this group df with the original dataframe to get the tumor volume at the last timepoint


Ca = cleanedData.loc[cleanedData['Drug Regimen'] == "Capomulin"]
R = cleanedData.loc[cleanedData['Drug Regimen'] =="Ramicane"]
I = cleanedData.loc[cleanedData['Drug Regimen'] =="Infubinol"]
Ce = cleanedData.loc[cleanedData['Drug Regimen'] =="Ceftamin"]

# %%
# Put treatments into a list for for loop (and later for plot labels)
treatmentLabels = ["Capomulin", "Ramicane", "Infubinol","Ceftamin"]

# Create empty list to fill with tumor vol data (for plotting)
tumorVolCa = Ca["Tumor Volume (mm3)"]
tumorVolR = R["Tumor Volume (mm3)"]
tumorVolI= I["Tumor Volume (mm3)"]
tumorVolCe = Ce["Tumor Volume (mm3)"]

# Calculate the IQR and quantitatively determine if there are any potential outliers. 
    # Locate the rows which contain mice on each drug and get the tumor volumes
    # add subset 
    # Determine outliers using upper and lower bounds
    
Caquart = tumorVolCa.quantile([.25,.50,.75])
CaUpperQ = Caquart[.75]
CaLowerQ = Caquart[.25]
CaIqr = CaUpperQ - CaLowerQ
LBCa = CaLowerQ - (1.5*CaIqr)
UBCa = CaUpperQ + (1.5*CaIqr)
CaOutliers=(Ca.loc[(Ca['Tumor Volume (mm3)'] < LBCa)| (Ca['Tumor Volume (mm3)']> UBCa)])
print(f"Capomulin Ourliers: {CaOutliers['Tumor Volume (mm3)']}")

Rquart = tumorVolR.quantile([.25,.50,.75])
RUpperQ = Rquart[.75]
RLowerQ = Rquart[.25]
RIqr = RUpperQ - RLowerQ
LBR = RLowerQ - (1.5*RIqr)
UBR = RUpperQ + (1.5*RIqr)

ROutliers=(R.loc[(R['Tumor Volume (mm3)'] < LBR)|(R['Tumor Volume (mm3)']> UBR)])
print(f"Ramicane Ourliers: {ROutliers['Tumor Volume (mm3)']}")

Iquart = tumorVolI.quantile([.25,.50,.75])
IUpperQ = Iquart[.75]
ILowerQ = Iquart[.25]
IIqr = IUpperQ - ILowerQ
LBI = ILowerQ - (1.5*IIqr)
UBI = IUpperQ + (1.5*IIqr)
IOutliers=(I.loc[(I['Tumor Volume (mm3)'] < LBI)|(I['Tumor Volume (mm3)']> UBI)])
print(f"Infubinol Ourliers: {IOutliers['Tumor Volume (mm3)']}")

Cequart = tumorVolCe.quantile([.25,.50,.75])
CeUpperQ = Cequart[.75]
CeLowerQ = Cequart[.25]
CeIqr = CeUpperQ - CeLowerQ
LBCe = CeLowerQ - (1.5*CeIqr)
UBCe = CeUpperQ + (1.5*CeIqr)
CeOutliers=(Ce.loc[(Ce['Tumor Volume (mm3)'] < LBCe)|(Ce['Tumor Volume (mm3)']> UBCe)])
#print(f"Ceftamin Ourliers: {CeOutliers['Tumor Volume (mm3)']}")
# Out:
# Capomulin Ourliers: Series([], Name: Tumor Volume (mm3), dtype: float64)
# Ramicane Ourliers: Series([], Name: Tumor Volume (mm3), dtype: float64)
# Infubinol Ourliers: 669    36.321346
# Name: Tumor Volume (mm3), dtype: float64

# %%
# Generate a box plot of the final tumor volume of each mouse across four regimens of interest
fig1, ax1 = plt.subplots()
ax1.boxplot([tumorVolCa,tumorVolR,tumorVolI,tumorVolCe])
ax1.set_xticklabels(treatmentLabels)
ax1.set_ylabel('Final Tumor Volume (mm3)')
plt.show()

# %% [markdown]
# ## Line and Scatter Plots

# %%
# Generate a line plot of tumor volume vs. time point for a mouse treated with Capomulin
mouseData = combined_data.loc[combined_data["Mouse ID"] =="k403"]
xAxis = mouseData['Timepoint']
yAxis = mouseData['Tumor Volume (mm3)']

plt.plot(xAxis,yAxis)
plt.title('Analysis of Tumor Volume')
plt.xlabel('Timepoints')
plt.ylabel('Tumor Volume (mm3)')
plt.show()

# %%
# Generate a scatter plot of average tumor volume vs. mouse weight for the Capomulin regimen
xAxis = Ca["Weight (g)"]
yAxis = Ca["Tumor Volume (mm3)"]

plt.scatter(xAxis,yAxis)
plt.title('Tumor Growth Analysis Based on Weight')
plt.xlabel('Weight (g)')
plt.ylabel('Tumor Volume (mm3)')
plt.show()

# %% [markdown]
# ## Correlation and Regression

# %%
# Calculate the correlation coefficient and linear regression model 
# for mouse weight and average tumor volume for the Capomulin regimen
(slope, intercept, rvalue, pvalue, stderr) = linregress(xAxis,yAxis)
regress_values = xAxis*slope + intercept
equation = "y = "+ str(round(slope,2)) + "x " + str(round(intercept,2))

plt.scatter(xAxis,yAxis)
plt.plot(xAxis,regress_values,"r-")
plt.annotate(equation,(6,10),fontsize=15,color="red")
plt.title('Tumor Growth Analysis Based on Weight')
plt.xlabel('Weight (g)')
plt.ylabel('Tumor Volume (mm3)')
plt.show()
